# %% [markdown]
# # 03 · EfficientNet classification baseline (OPTIONAL)
#
# Experimental comparison only — NOT the production pipeline. Requires bird
# crops derived from verified bounding boxes laid out as
# `crops/{train,val,test}/{class}/`.

# %% [markdown]
# ## Train
# > **PENDING OUTPUT** — this cell has not been executed because the dataset/model is not present in this environment. Run it after preparing the data (see ml/README.md). No outputs are fabricated.

# %%
import sys; import os; sys.path.insert(0, os.path.abspath('..'))
from pathlib import Path

from src.training.train_efficientnet import train

data = Path('../data/crops')
if data.exists():
    train(str(data), epochs=15, imgsz=224, batch=32, lr=1e-3)
else:
    print('No crops at', data, '— generate crops from verified boxes first.')
